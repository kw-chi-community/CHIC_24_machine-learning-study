# %%
pip install palmerpenguins
# Out:
# Requirement already satisfied: palmerpenguins in c:\users\charl\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: pandas in c:\users\charl\anaconda3\lib\site-packages (from palmerpenguins) (1.5.3)
# Requirement already satisfied: numpy in c:\users\charl\anaconda3\lib\site-packages (from palmerpenguins) (1.25.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\charl\anaconda3\lib\site-packages (from pandas->palmerpenguins) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\charl\anaconda3\lib\site-packages (from pandas->palmerpenguins) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\charl\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->palmerpenguins) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\charl\anaconda3\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\charl\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\charl\anaconda3\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\charl\anaconda3\lib\site-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\charl\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)

# %%
import pandas as pd
import seaborn as sns 
from palmerpenguins import load_penguins
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
penguins = load_penguins()
#penguins.replace('', np.nan, inplace=True)
penguins = penguins.dropna()
penguins['species'].value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 4         3450.0  female  2007
# 5         3650.0    male  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [333 rows x 8 columns]

# %%
penguins['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
labels = penguins['species'].unique()
for item in labels:
    plt.scatter(x=penguins[penguins['species']==item]['bill_length_mm'], y=penguins[penguins['species']==item]['bill_depth_mm'], alpha=0.7) 
plt.legend(labels=labels)

# %%
labels = penguins['species'].unique()
for item in labels:
    plt.scatter(x=penguins[penguins['species']==item]['flipper_length_mm'], y=penguins[penguins['species']==item]['body_mass_g'], alpha=0.7) 
plt.legend(labels=labels)

# %%
penguinSpecies = penguins['species']
penguinData = penguins[]

# %%
pca = PCA(n_components=2)
df = pca.fit_transform(penguins)
dfRes1 = pd.DataFrame(df, columns=['X', 'Y'])
dfRes1['Class'] = dfClass
dfRes1

# %%
# K-Means 클러스터링 함수 실행 후 차트 가시화
def k_Means_Plot(Data, Select_k, NAME, Init_Method = 'k-means++', Num_Init=10):
    Data2 = Data[['X', 'Y']]    
    fig, axes = plt.subplots(1, (np.max(list(Select_k))-np.min(list(Select_k)))+1, figsize=(15, 4))
    for i in Select_k:
        Kmeans_Clustering = KMeans(n_clusters=i, init=Init_Method, random_state=2020, n_init=Num_Init)
        Kmeans_Clustering.fit(Data2)
        mglearn.discrete_scatter(Data2['X'], Data2['Y'], Kmeans_Clustering.labels_, ax=axes[i - 2], s=5)
        mglearn.discrete_scatter(Kmeans_Clustering.cluster_centers_[:, 0], 
                                 Kmeans_Clustering.cluster_centers_[:, 1],
                                 list(range(i)), 
                                 markeredgewidth=3, 
                                 ax=axes[i - 2], s=10)
        Score = np.round(silhouette_score(Data2, Kmeans_Clustering.labels_),3)
        axes[i - 2].set_title( NAME + ' / k = ' + str(i)+' / S_Score:'+str(Score))
        
k_Means_Plot(Data = penguins, Select_k = range(2, 5), NAME = "penguin", Init_Method='random', Num_Init=10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 17
#      14         Score = np.round(silhouette_score(Data2, Kmeans_Clustering.labels_),3)
#      15         axes[i - 2].set_title( NAME + ' / k = ' + str(i)+' / S_Score:'+str(Score))
# ---> 17 k_Means_Plot(Data = penguins, Select_k = range(2, 5), NAME = "penguin", Init_Method='random', Num_Init=10)
#
# Cell In[23], line 3, in k_Means_Plot(Data, Select_k, NAME, Init_Method, Num_Init)
#       2 def k_Means_Plot(Data, Select_k, NAME, Init_Method = 'k-means++', Num_Init=10):
# ----> 3     Data2 = Data[['X', 'Y']]
#       4     fig, axes = plt.subplots(1, (np.max(list(Select_k))-np.min(list(Select_k)))+1, figsize=(15, 4))
#       5     for i in Select_k:
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['X', 'Y'], dtype='object')] are in the [columns]"
